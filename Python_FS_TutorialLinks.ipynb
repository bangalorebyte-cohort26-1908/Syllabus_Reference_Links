# %% [markdown]
# PYTHON FULL STACK - Tutorial Links
# ================================

# %% [markdown]
# Phase 2.1
# --------------
#
# **Introduction to Web Development
#
# => https://www.youtube.com/watch?v=HVsySz-h9r4   (Git Tutorial for Beginners: Command-Line Fundamentals)
#
# > Web Development Introduction
# > Web Scraping using beautiful soup and selenium
# > Introduction to HTML, CSS and Java Script
#
# => https://www.youtube.com/watch?v=UB1O30fR-EE   (HTML Crash Course For Absolute Beginners)
#
# => https://developer.mozilla.org/en-US/docs/Web/HTML   ()
#
#
#
# > Introduction to HTML, CSS and Java Script
#
# => https://www.youtube.com/watch?v=yfoY53QXEnI&t=1380s   (CSS Crash Course)
#
# => https://youtu.be/5GcQtLDGXy8   (Bootstrap Beginner Crash Course)
#
#
#
# => Video Tutorial : https://www.youtube.com/watch?v=yfoY53QXEnI
#
# => Reference : https://developer.mozilla.org/en-US/docs/Web/CSS
#
#
#
# Introduction to Bootstrap
# Reference Video --> https://www.youtube.com/watch?v=5GcQtLDGXy8&t=1360s
# Documentation --> https://getbootstrap.com/
#
# Foundation CSS
# Reference Video --> https://www.youtube.com/watch?v=DEu5xYEZx18&t=2136s
# Documentaion --> https://foundation.zurb.com/
#
# Bulma CSS
# Reference Video --> https://youtu.be/IiPQYQT2-wg
# Documentation --> https://bulma.io/
#
# Materialize CSS
# Reference Video --> https://youtu.be/nqT8c5OFjEQ
# Documentaion --> https://materializecss.com/
#
# Sass Framework
# Reference Video --> https://youtu.be/zPFsgxPb430
# Documentation --> https://sass-lang.com/
#
# Less Framework
# Reference Video --> https://youtu.be/YD91G8DdUsw
# Documentaion --> http://lesscss.org/
#
#
#
# => https://www.youtube.com/watch?v=yfoY53QXEnI&t=1380s   (CSS Crash Course)
#
# => https://youtu.be/5GcQtLDGXy8   (Bootstrap Beginner Crash Course)
#
#
# > Introduction to Pandas and Matplotlib
#
# ---> Introduction to Pandas (10 minutes to Pandas) - https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html
# ---> Kevin Markhams Pandas Playlist (Dataschool) - https://www.youtube.com/playlist?list=PL5-da3qGB5ICCsgW1MxlZ0Hq8LL5U3u9y
#
# ---> Corey Schafer's Video on Introduction to Matplotlib - https://www.youtube.com/watch?v=UO98lJQ3QGI
# ---> Corey Schafer's 10 part video playlist for Matplotlib - https://www.youtube.com/playlist?list=PL-osiE80TeTvipOqomVEeZ1HRrcEvtZB_
#
# > Review phase 1
# > Phase 1 Assessment  # #
# > Weekend - Front End Static Web Page Assignment

# %% [markdown]
# > Web Development Introduction
#
# =>
#
# > Web Scraping using beautiful soup and selenium
#
# =>
#
#
# > Introduction to Pandas and Matplotlib
#
#
# > Review phase 1
# > Phase 1 Assessment
# > Weekend - Front End Static Web Page Assignment

# %% [markdown]
# Phase 2.2
# --------------
#
# **Deeper into Front end
#
# > Quiz 4 - Week 4 Syllabus
# > Review intro to HTML, CSS, and JavaScript
# > Higher Order Functions, Call-backs, Closure
# > JavaScript Scope
#
# => https://www.youtube.com/watch?v=hdI2bqOjy3c   (JavaScript Crash Course For Beginners)
#
# => Reference Video Tutorial - https://www.youtube.com/watch?v=hdI2bqOjy3c&t=3699s
#
# => https://www.youtube.com/watch?v=2LeqilIw-28&list=PLillGF-RfqbZ7s3t6ZInY3NjEOOX7hsBv
#
# > Document Object Model
#
# > Event Listeners
# > jQuery
#
# JQuery_AJAX
# https://www.youtube.com/watch?v=3nrLc_JOF7k
#
# => https://www.youtube.com/watch?v=hdI2bqOjy3c&list=PLillGF-RfqbbnEGy3ROiLWk7JMCuSyQtX
#
#
# > CSS Specificity
# > CSS Pseudo Classes
# > CSS Positioning
# > CSS Media Queries
# > CSS Grid Systems
# > CSS Responsive Design
#
# > Chrome Dev Tools
#
# => https://www.youtube.com/watch?v=x4q86IjJFag
#
# > Weekend - Building Tic Tac Toe, Blackjack, Connect Four

# %% [markdown]
# Phase 2.3
# --------------
#
# **Python Web Frameworks Flask
#
# > Quiz 5 - Week 5 Syllabus
# > Setting up virtual environments
# > Introduction to Flask Request Response Cycle
#
# => Introduction to Flask
# Pipenv tutorial - Youtube - https://www.youtube.com/watch?v=zDYL22QNiWk
# Flask Tutorial - Youtube - https://youtu.be/MwZwr5Tvyxo?list=PL-osiE80TeTs4UjLw5MM6OjgkjFeUxCYH
#
# => https://www.youtube.com/watch?v=Z1RJmh_OqeA
#
# => https://www.youtube.com/watch?v=zdgYw-3tzfI
#
# > What is the Request Object?
# > HTML Forms
# > Jinja Templating
#
# => https://jinja.palletsprojects.com/en/2.10.x/
#
# => https://jinja.palletsprojects.com/en/2.10.x/api/#basics
#
# => https://jinja.palletsprojects.com/en/2.10.x/templates/
#
# > HTTP Verbs
#
# => https://www.youtube.com/watch?v=iYM2zFP3Zn0   (HTTP Crash Course & Exploration)
#
# > Sending a response in different formats. (JSON, HTML Templates)
# > SQLAlchemy Introduction
#
# => https://flask-sqlalchemy.palletsprojects.com/en/2.x/quickstart/
#
# => Flask SQL alchemy reading materials
# https://docs.sqlalchemy.org/en/13/
# https://flask-sqlalchemy.palletsprojects.com/en/2.x/models/
# Flask SQL alchemy Video - https://www.youtube.com/watch?v=cYWiDiIUxQc
#
#
#
# > (Weekend) - Building a full stack web application that will make requests to HTTP API’s,
# and persist information in a SQL database. Utilize HTML, CSS, JavaScript, AJAX, Flask, and SQL
#
# => https://www.youtube.com/watch?v=pmRT8QQLIqk   (Deploying Flask to Heroku)
#
# => https://medium.com/the-andela-way/deploying-a-python-flask-app-to-heroku-41250bda27d0   (Deploying a Python Flask app on Heroku)
#
# => https://www.youtube.com/watch?v=CjYKrbq8BCw&list=PLXmMXHVSvS-CoYS177-UvMAQYRfL3fBtX
#
# => https://github.com/CoreyMSchafer/code_snippets/tree/master/Python/Flask_Blog

# %% [markdown]
# Phase 2.4
# --------------
#
# **Python Web Frameworks - Django
#
# > Quiz 6 - Week 6 Syllabus
# > Introduction to Django
# > Django Directory Structure
# > Django Models
# > Django Forms / Templating
# > Building more full stack applications
#
# => https://docs.djangoproject.com/en/2.2/intro/tutorial03/
#
# > Review for Phase 2 Assessment
#
# => https://www.youtube.com/watch?v=UmljXZIypDc&list=PL-osiE80TeTtoQCKZ03TU5fNfx2UY6U4p
#
# => https://www.youtube.com/watch?v=F5mRW0jo-U4
#
# => https://www.youtube.com/watch?v=QVX-etwgvJ8&list=PLXmMXHVSvS-DQfOsQdXkzEZyD0Vei7PKf

# %% [markdown]
# Phase 3.1
# --------------
#
# **Java Script Frameworks and Deeper into Backend
#
# > Quiz 7 - Week 7 Syllabus
# > Angular JS, Node JS, React JS D3.js / C3.js AJAX
#
# => https://www.youtube.com/watch?v=fBNz5xF-Kx4
#
# => https://www.youtube.com/watch?v=Fdf5aTYRW0E
#
# => https://www.youtube.com/watch?v=sBws8MSXN7A
#
# => https://www.youtube.com/watch?v=DLX62G4lc44
#
# => https://www.youtube.com/watch?v=nzshmMlOuwI
#
# > Introduction
# > What happens when you type google.com in the browser?
# > Password Hashing
# > User Sessions
# > REST APIs
#
# => https://www.youtube.com/watch?v=PTZiDnuC86g   (REST API With Flask & SQL Alchemy)
#
# => https://www.youtube.com/watch?v=tG6O8YF91HE   (Build a Rest API with the Django REST Framework)
#
# > Single Page Applications
# > (Weeklong / Weekend Part 1) - 2-3 days building a RESTful API in Flask that will talk to a SQL Database,
# accept requests, and return JSON Responses
# > (Weeklong / Weekend Part 2) - 2-3 days building a Single Page Application that will consume the RESTful API
# just built using HTML, CSS, JS, AJAX, and Flask

# %% [markdown]
# Phase 3.2
# --------------
#
# **Final Project Phase, Deep Dive Lectures, and Mock Interviews
#
# > Students Lectures – ES6, Flexbox, SASS/SCS
# > Students will do 3 projects
# > Each project done in 2 week sprints
# > There will be 1 group project, 1 solo project, and the third project is optional between solo or group Deploy Final Projects on Digital Ocean
